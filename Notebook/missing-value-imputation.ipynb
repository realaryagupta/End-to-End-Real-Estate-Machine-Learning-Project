# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
path = '/Users/aryagupta/Desktop/Capstone Project/Data/processed/gurgaon_properties_outlier_treated.csv'

df = pd.read_csv(path)

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat      signature global park 4   sector 36   0.82
# 1          flat             smart world gems   sector 89   0.95
# 2          flat       breez global hill view  sohna road   0.32
# 3          flat  bestech park view sanskruti   sector 92   1.60
# 4          flat               suncity avenue  sector 102   0.48
#
#    price_per_sqft    area                                       areaWithType  \
# 0          7586.0  1081.0  Super Built up area 1081(100.43 sq.m.)Carpet a...
# 1          8597.0  1105.0                   Carpet area: 1103 (102.47 sq.m.)
# 2          5470.0   585.0  Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...
# 3          8020.0  1995.0  Super Built up area 1995(185.34 sq.m.)Built Up...
# 4          9023.0   532.0  Super Built up area 632(58.71 sq.m.)Carpet are...
#
#    bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 0        3         2       2       2.0         NaN    New Property
# 1        2         2       2       4.0         NaN    New Property
# 2        2         2       1      17.0         NaN    New Property
# 3        3         4      3+      10.0  North-West  Relatively New
# 4        2         2       1       5.0  North-East  Relatively New
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0               1081.0            NaN        650.0           0             0
# 1                  NaN            NaN       1103.0           1             1
# 2                  NaN         1000.0        585.0           0             0
# 3               1995.0         1615.0       1476.0           0             1
# 4                632.0            NaN        532.0           0             0
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                0             8
# 1           0           0       0                0            38
# 2           0           0       0                0            49
# 3           0           0       1                1           174
# 4           1           0       0                0           159

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                 17
# facing                 1029
# agePossession             0
# super_built_up_area    1713
# built_up_area          1975
# carpet_area            1738
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# dtype: int64

# %% [markdown]
# ### Built up area

# %%
sns.scatterplot(x=df['built_up_area'], y=df['super_built_up_area'])
# Out:
# <Axes: xlabel='built_up_area', ylabel='super_built_up_area'>

# %%
sns.scatterplot(x=df['built_up_area'], y=df['carpet_area'])
# Out:
# <Axes: xlabel='built_up_area', ylabel='carpet_area'>

# %%
((df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & (df['carpet_area'].isnull()))
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3583    False
# 3584    False
# 3585    False
# 3586    False
# 3587    False
# Length: 3588, dtype: bool

# %%
all_present_df = df[~((df['super_built_up_area'].isnull()) | (df['built_up_area'].isnull()) | (df['carpet_area'].isnull()))]

# %%
all_present_df.shape
# Out:
# (531, 23)

# %%
super_to_built_up_ratio = (all_present_df['super_built_up_area']/all_present_df['built_up_area']).median()

# %%
carpet_to_built_up_ratio = (all_present_df['carpet_area']/all_present_df['built_up_area']).median()

# %%
print(super_to_built_up_ratio, carpet_to_built_up_ratio)
# Out:
# 1.105263157894737 0.9

# %%
# both present built up null
sbc_df = df[~(df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & ~(df['carpet_area'].isnull())]

# %%
sbc_df.head()
# Out:
#    property_type                  society      sector  price  price_per_sqft  \
# 0           flat  signature global park 4   sector 36   0.82          7586.0
# 4           flat           suncity avenue  sector 102   0.48          9023.0
# 39          flat             corona optus   sector 37   1.25          7176.0
# 41          flat               m3m merlin   sector 67   2.80         13679.0
# 46          flat      smart world orchard   sector 61   2.10         13752.0
#
#       area                                       areaWithType  bedRoom  \
# 0   1081.0  Super Built up area 1081(100.43 sq.m.)Carpet a...        3
# 4    532.0  Super Built up area 632(58.71 sq.m.)Carpet are...        2
# 39  1742.0  Super Built up area 1735(161.19 sq.m.)Carpet a...        3
# 41  2047.0  Super Built up area 2047(190.17 sq.m.)Carpet a...        3
# 46  1527.0  Super Built up area 1549(143.91 sq.m.)Carpet a...        3
#
#     bathroom balcony  floorNum      facing       agePossession  \
# 0          2       2       2.0         NaN        New Property
# 4          2       1       5.0  North-East      Relatively New
# 39         3       3       2.0  North-West      Relatively New
# 41         3       3       5.0  North-East      Moderately Old
# 46         2       3       3.0       South  Under Construction
#
#     super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0                1081.0            NaN        650.0           0             0
# 4                 632.0            NaN        532.0           0             0
# 39               1735.0            NaN       1400.0           1             0
# 41               2047.0            NaN       1880.0           0             1
# 46               1549.0            NaN       1500.0           0             0
#
#     store room  pooja room  others  furnishing_type  luxury_score
# 0            0           0       0                0             8
# 4            1           0       0                0           159
# 39           0           0       0                0            49
# 41           0           0       0                2            26
# 46           0           0       0                0           146

# %%
sbc_df['built_up_area'].fillna(round(((sbc_df['super_built_up_area']/1.105) + (sbc_df['carpet_area']/0.9))/2),inplace=True)
# Out:
# /var/folders/vr/nc9jvld12q115x_g_114k8g40000gn/T/ipykernel_2601/1215074969.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sbc_df['built_up_area'].fillna(round(((sbc_df['super_built_up_area']/1.105) + (sbc_df['carpet_area']/0.9))/2),inplace=True)
# /var/folders/vr/nc9jvld12q115x_g_114k8g40000gn/T/ipykernel_2601/1215074969.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sbc_df['built_up_area'].fillna(round(((sbc_df['super_built_up_area']/1.105) + (sbc_df['carpet_area']/0.9))/2),inplace=True)

# %%
df.update(sbc_df)

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                 17
# facing                 1029
# agePossession             0
# super_built_up_area    1713
# built_up_area          1554
# carpet_area            1738
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# dtype: int64

# %%
# sb present c is null built up null
sb_df = df[~(df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & (df['carpet_area'].isnull())]

# %%
sb_df.head()
# Out:
#    property_type                      society       sector  price  \
# 5           flat               paras quartier  gwal pahari   7.50
# 6           flat       experion the heartsong   sector 108   2.00
# 7           flat      adani m2k oyster grande   sector 102   1.90
# 12          flat               ats tourmaline   sector 109   2.25
# 15          flat  bestech park view sanskruti    sector 92   1.55
#
#     price_per_sqft    area                            areaWithType  bedRoom  \
# 5          14019.0  5350.0  Super Built up area 5350(497.03 sq.m.)        4
# 6           8554.0  2338.0  Super Built up area 2338(217.21 sq.m.)        3
# 7           9104.0  2087.0  Super Built up area 1889(175.49 sq.m.)        3
# 12          8704.0  2585.0  Super Built up area 2585(240.15 sq.m.)        3
# 15          7568.0  2048.0  Super Built up area 1995(185.34 sq.m.)        3
#
#     bathroom balcony  floorNum      facing   agePossession  \
# 5          4      3+      20.0  North-East    New Property
# 6          3      3+      14.0        East  Relatively New
# 7          4       3       8.0  North-East  Relatively New
# 12         4       3      14.0  North-East  Relatively New
# 15         4       3      16.0       South  Relatively New
#
#     super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 5                5350.0            NaN          NaN           0             1
# 6                2338.0            NaN          NaN           0             1
# 7                1889.0            NaN          NaN           0             1
# 12               2585.0            NaN          NaN           0             1
# 15               1995.0            NaN          NaN           0             1
#
#     store room  pooja room  others  furnishing_type  luxury_score
# 5            0           1       1                1            49
# 6            0           0       0                0            95
# 7            0           0       0                0           165
# 12           0           0       0                0           101
# 15           0           0       0                1            60

# %%
sb_df['built_up_area'].fillna(round(sb_df['super_built_up_area']/1.105),inplace=True)
# Out:
# /var/folders/vr/nc9jvld12q115x_g_114k8g40000gn/T/ipykernel_2601/1714170073.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sb_df['built_up_area'].fillna(round(sb_df['super_built_up_area']/1.105),inplace=True)
# /var/folders/vr/nc9jvld12q115x_g_114k8g40000gn/T/ipykernel_2601/1714170073.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sb_df['built_up_area'].fillna(round(sb_df['super_built_up_area']/1.105),inplace=True)

# %%
df.update(sb_df)

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                 17
# facing                 1029
# agePossession             0
# super_built_up_area    1713
# built_up_area           679
# carpet_area            1738
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# dtype: int64

# %%
# sb null c is present built up null
c_df = df[(df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & ~(df['carpet_area'].isnull())]

# %%
c_df.head()
# Out:
#    property_type                           society     sector  price  \
# 1           flat                  smart world gems  sector 89   0.95
# 11          flat                  dlf regency park  sector 28   1.60
# 13          flat  emaar mgf emerald floors premier  sector 65   2.77
# 19          flat               afnhb jalvayu vihar  sector 30   0.85
# 25          flat                chanderlok society  sector 28   0.90
#
#     price_per_sqft    area                      areaWithType  bedRoom  \
# 1           8597.0  1105.0  Carpet area: 1103 (102.47 sq.m.)        2
# 11         14545.0  1100.0  Carpet area: 1100 (102.19 sq.m.)        2
# 13         14025.0  1975.0  Carpet area: 1975 (183.48 sq.m.)        4
# 19         12859.0   661.0    Carpet area: 661 (61.41 sq.m.)        2
# 25          7235.0  1244.0  Carpet area: 1244 (115.57 sq.m.)        4
#
#     bathroom balcony  floorNum      facing   agePossession  \
# 1          2       2       4.0         NaN    New Property
# 11         2       2       3.0       North  Relatively New
# 13         4      3+       3.0  North-East  Relatively New
# 19         2       1       2.0        West    Old Property
# 25         2      3+       1.0         NaN    Old Property
#
#     super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 1                   NaN            NaN       1103.0           1             1
# 11                  NaN            NaN       1100.0           0             0
# 13                  NaN            NaN       1975.0           1             1
# 19                  NaN            NaN        661.0           0             0
# 25                  NaN            NaN       1244.0           0             0
#
#     store room  pooja room  others  furnishing_type  luxury_score
# 1            0           0       0                0            38
# 11           0           0       0                0            52
# 13           0           0       0                2           174
# 19           0           0       1                1            49
# 25           0           0       0                0             0

# %%
c_df['built_up_area'].fillna(round(c_df['carpet_area']/0.9),inplace=True)
# Out:
# /var/folders/vr/nc9jvld12q115x_g_114k8g40000gn/T/ipykernel_2601/2136919732.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   c_df['built_up_area'].fillna(round(c_df['carpet_area']/0.9),inplace=True)
# /var/folders/vr/nc9jvld12q115x_g_114k8g40000gn/T/ipykernel_2601/2136919732.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c_df['built_up_area'].fillna(round(c_df['carpet_area']/0.9),inplace=True)

# %%
df.update(c_df)

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                 17
# facing                 1029
# agePossession             0
# super_built_up_area    1713
# built_up_area             0
# carpet_area            1738
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# dtype: int64

# %%
sns.scatterplot(x=df['built_up_area'], y=df['price'])
# Out:
# <Axes: xlabel='built_up_area', ylabel='price'>

# %%
anamoly_df = df[(df['built_up_area'] < 2000) & (df['price'] > 2.5)][['price','area','built_up_area']]

# %%
anamoly_df.sample(5)
# Out:
#       price    area  built_up_area
# 1698   4.49  3150.0          389.0
# 2225   3.15  2153.0          222.0
# 544    2.80  1650.0         1800.0
# 1809   3.75  1701.0         1701.0
# 1966   4.50  1350.0         1350.0

# %%
anamoly_df['built_up_area'] = anamoly_df['area']

# %%
df.update(anamoly_df)

# %%
sns.scatterplot(x = df['built_up_area'], y =df['price'])
# Out:
# <Axes: xlabel='built_up_area', ylabel='price'>

# %%
df.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areaWithType', 'bedRoom', 'bathroom', 'balcony', 'floorNum', 'facing',
#        'agePossession', 'super_built_up_area', 'built_up_area', 'carpet_area',
#        'study room', 'servant room', 'store room', 'pooja room', 'others',
#        'furnishing_type', 'luxury_score'],
#       dtype='object')

# %%
df.drop(columns=['area','areaWithType','super_built_up_area','carpet_area'], axis = 1,inplace=True)

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat      signature global park 4   sector 36   0.82
# 1          flat             smart world gems   sector 89   0.95
# 2          flat       breez global hill view  sohna road   0.32
# 3          flat  bestech park view sanskruti   sector 92   1.60
# 4          flat               suncity avenue  sector 102   0.48
#
#    price_per_sqft  bedRoom  bathroom balcony  floorNum      facing  \
# 0          7586.0        3         2       2       2.0         NaN
# 1          8597.0        2         2       2       4.0         NaN
# 2          5470.0        2         2       1      17.0         NaN
# 3          8020.0        3         4      3+      10.0  North-West
# 4          9023.0        2         2       1       5.0  North-East
#
#     agePossession  built_up_area  study room  servant room  store room  \
# 0    New Property          850.0           0             0           0
# 1    New Property         1226.0           1             1           0
# 2    New Property         1000.0           0             0           0
# 3  Relatively New         1615.0           0             1           0
# 4  Relatively New          582.0           0             0           1
#
#    pooja room  others  furnishing_type  luxury_score
# 0           0       0                0             8
# 1           0       0                0            38
# 2           0       0                0            49
# 3           0       1                1           174
# 4           0       0                0           159

# %%
df.isnull().sum()
# Out:
# property_type         0
# society               1
# sector                0
# price                 0
# price_per_sqft        0
# bedRoom               0
# bathroom              0
# balcony               0
# floorNum             17
# facing             1029
# agePossession         0
# built_up_area         0
# study room            0
# servant room          0
# store room            0
# pooja room            0
# others                0
# furnishing_type       0
# luxury_score          0
# dtype: int64

# %% [markdown]
# ### floorNum

# %%
df[df['floorNum'].isnull()]
# Out:
#      property_type                  society             sector  price  \
# 505          house              independent           sector 4   0.65
# 774          house              independent           sector 7   6.50
# 1303         house              independent           sector 3   1.50
# 1462         house       vipul tatvam villa          sector 48   8.50
# 1475         house  ansal sushant lok plots          sector 43   3.30
# 1967         house               jacob pura          sector 12   0.35
# 2069         house       vipul tatvam villa          sector 48   8.50
# 2178         house              independent           sector 4   4.12
# 2294         house       emaar mgf marbella          sector 66   9.00
# 2462         house     dlf new town heights          sector 86   2.47
# 2559          flat                      NaN          sector 78   0.60
# 2568         house        ansal sushant lok          sector 43  10.50
# 2944         house              independent          sector 25  13.00
# 2994         house              independent          sector 24   1.45
# 3150         house              independent          sector 26   4.60
# 3245          flat       experion heartsong  dwarka expressway   1.08
# 3286         house              independent           sector 2   5.60
#
#       price_per_sqft  bedRoom  bathroom balcony  floorNum      facing  \
# 505          11111.0        4         2       2       NaN         NaN
# 774          15046.0        3         2      3+       NaN         NaN
# 1303         10288.0        3         3       0       NaN         NaN
# 1462         26235.0        4         4       1       NaN         NaN
# 1475         26570.0        1         1       0       NaN         NaN
# 1967          9722.0        2         1       0       NaN         NaN
# 2069         26235.0        4         4       2       NaN        East
# 2178          8889.0        2         1      3+       NaN         NaN
# 2294         21251.0        4         4      3+       NaN  South-West
# 2462          7719.0        4         4      3+       NaN        West
# 2559          3692.0        2         2       0       NaN         NaN
# 2568         27911.0        4         4       2       NaN  North-East
# 2944         45710.0        6         8      3+       NaN         NaN
# 2994          2984.0        3         3       1       NaN         NaN
# 3150         12198.0        4         4      3+       NaN         NaN
# 3245          6150.0        3         3       0       NaN         NaN
# 3286         17284.0        8         6      3+       NaN  South-West
#
#            agePossession  built_up_area  study room  servant room  store room  \
# 505       Moderately Old          585.0           0             0           0
# 774         Old Property         4320.0           0             0           0
# 1303        Old Property          210.0           0             0           0
# 1462      Relatively New         3240.0           0             0           0
# 1475  Under Construction         1242.0           0             0           0
# 1967        Old Property          360.0           0             0           0
# 2069      Moderately Old         3240.0           0             1           1
# 2178      Moderately Old         4635.0           0             0           0
# 2294      Relatively New         5200.0           0             1           1
# 2462      Moderately Old         2800.0           0             1           0
# 2559  Under Construction         1625.0           0             0           0
# 2568        Old Property         3762.0           0             1           0
# 2944      Relatively New         2844.0           1             1           1
# 2994        Old Property          540.0           0             0           0
# 3150        Old Property         3771.0           0             0           0
# 3245  Under Construction         1758.0           0             0           0
# 3286      Moderately Old         3240.0           1             1           1
#
#       pooja room  others  furnishing_type  luxury_score
# 505            0       0                0             0
# 774            0       0                0             9
# 1303           0       0                0             0
# 1462           0       0                0            21
# 1475           0       0                0             0
# 1967           0       0                0             0
# 2069           1       0                0            88
# 2178           0       0                0             0
# 2294           1       0                1           114
# 2462           1       0                1           130
# 2559           0       0                0             0
# 2568           0       0                0            59
# 2944           1       0                2             0
# 2994           0       0                0             9
# 3150           0       0                0            28
# 3245           0       0                0             0
# 3286           1       0                0             0

# %%
df[df['property_type'] == 'house']['floorNum'].median()
# Out:
# np.float64(2.0)

# %%
df['floorNum'].fillna(2.0,inplace=True)
# Out:
# /var/folders/vr/nc9jvld12q115x_g_114k8g40000gn/T/ipykernel_2601/15612474.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['floorNum'].fillna(2.0,inplace=True)

# %%
df.isnull().sum()
# Out:
# property_type         0
# society               1
# sector                0
# price                 0
# price_per_sqft        0
# bedRoom               0
# bathroom              0
# balcony               0
# floorNum              0
# facing             1029
# agePossession         0
# built_up_area         0
# study room            0
# servant room          0
# store room            0
# pooja room            0
# others                0
# furnishing_type       0
# luxury_score          0
# dtype: int64

# %%
1011/df.shape[0]
# Out:
# 0.2817725752508361

# %% [markdown]
# ### facing

# %%
df['facing'].value_counts().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df.drop(columns=['facing'],inplace=True)

# %%
df.sample(5)
# Out:
#      property_type                           society     sector  price  \
# 1819          flat              shree vardhman flora  sector 90   0.96
# 2851          flat       bestech park view residency   sector 2   1.55
# 994          house                     dlf the grove  sector 54   5.70
# 2390          flat  hsiidc sidco shivalik apartments    manesar   0.48
# 1908         house                       independent  sector 57   3.50
#
#       price_per_sqft  bedRoom  bathroom balcony  floorNum   agePossession  \
# 1819          5120.0        3         4       3       3.0    New Property
# 2851          8073.0        3         4      3+       4.0    Old Property
# 994          23457.0        4         4       0       1.0       Undefined
# 2390          3840.0        2         2       3       7.0  Moderately Old
# 1908         21605.0        4         4      3+       3.0    Old Property
#
#       built_up_area  study room  servant room  store room  pooja room  others  \
# 1819         1697.0           0             1           0           0       0
# 2851         1738.0           0             1           0           0       0
# 994          2430.0           0             0           0           0       0
# 2390          993.0           0             0           0           0       0
# 1908         1620.0           0             0           1           0       0
#
#       furnishing_type  luxury_score
# 1819                0           106
# 2851                0            84
# 994                 0            46
# 2390                0            88
# 1908                1            67

# %%
df.isnull().sum()
# Out:
# property_type      0
# society            1
# sector             0
# price              0
# price_per_sqft     0
# bedRoom            0
# bathroom           0
# balcony            0
# floorNum           0
# agePossession      0
# built_up_area      0
# study room         0
# servant room       0
# store room         0
# pooja room         0
# others             0
# furnishing_type    0
# luxury_score       0
# dtype: int64

# %%
df.drop(index=[2536],inplace=True)

# %%
df.isnull().sum()
# Out:
# property_type      0
# society            1
# sector             0
# price              0
# price_per_sqft     0
# bedRoom            0
# bathroom           0
# balcony            0
# floorNum           0
# agePossession      0
# built_up_area      0
# study room         0
# servant room       0
# store room         0
# pooja room         0
# others             0
# furnishing_type    0
# luxury_score       0
# dtype: int64

# %% [markdown]
# ### agePossession

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1609
# New Property           562
# Moderately Old         551
# Undefined              303
# Old Property           298
# Under Construction     264
# Name: count, dtype: int64
